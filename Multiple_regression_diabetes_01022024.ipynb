# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


data = pd.read_csv("diabetes.csv", index_col = 0)
data.head()
# Out:
#     encounter_id  patient_nbr             race  gender      age weight  \
# id
# 1        2278392      8222157        Caucasian  Female   [0-10)      ?
# 2         149190     55629189        Caucasian  Female  [10-20)      ?
# 3          64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 4         500364     82442376        Caucasian    Male  [30-40)      ?
# 5          16680     42519267        Caucasian    Male  [40-50)      ?
#
#     admission_type_id  discharge_disposition_id  admission_source_id  \
# id
# 1                   6                        25                    1
# 2                   1                         1                    7
# 3                   1                         1                    7
# 4                   1                         1                    7
# 5                   1                         1                    7
#
#     time_in_hospital  ... citoglipton insulin  glyburide.metformin  \
# id                    ...
# ...

# %%
#Simple linear regression

x = data.iloc[:,0].values
print(x)
y = data.iloc[:,12].values
y=y.reshape(-1,1)
x=x.reshape(-1,1)
# Out:
# [  2278392    149190     64410 ... 443854148 443857166 443867222]

# %%
diab_model = LinearRegression()

diab_model.fit(x,y)
y_pred = diab_model.predict(x)
plt.scatter(x,y,color = 'b')
plt.plot(x,diab_model.predict(x),color = 'r')
plt.title('\encounter_id vs num_lab_procedures')
plt.xlabel('num_lab_procedures')
plt.ylabel('encounter_id')
plt.show()
